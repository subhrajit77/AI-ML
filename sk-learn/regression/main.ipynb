# %% [markdown]
# #Basic Linear regression model

# %%
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression


np.random.seed(0)
X = 2 * np.random.rand(100,1)
y1= 5 + 3 * X + np.random.randn(100,1)
y2= -5 + 3 * X + np.random.randn(100,1)

y = np.random.uniform(low=y2, high=y1)

# lin_reg = LinearRegression()
# lin_reg.fit(X,y)
# y_pred = lin_reg.predict(X)

plt.scatter(X, y, color='yellow', label='Random Points')
plt.plot(X, 5 + 3*X, color='blue', label='Line with intercept 5')
plt.plot(X, -5 + 3*X,color='green', label='Line with intercept -5')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear regression with some Random points between 2 lines')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression


np.random.seed(0)
X = 2 * np.random.rand(100,1)
y1= 5 + 3 * X 
y2= -5 + 3 * X

y = np.random.uniform(low=y2, high=y1)

# lin_reg = LinearRegression()
# lin_reg.fit(X,y)
# y_pred = lin_reg.predict(X)

plt.scatter(X, y, color='yellow', label='Random Points')
plt.plot(X, y2, color='blue', label='Line with intercept 5')
plt.plot(X, y1,color='green', label='Line with intercept -5')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear regression with some Random points between 2 lines')
plt.legend()
plt.show()
